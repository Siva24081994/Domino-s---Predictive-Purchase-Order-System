# %%
# importing required libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_absolute_percentage_error
import warnings
warnings.filterwarnings('ignore')

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# !pip install tensorflow-macos
# Out:
# Collecting tensorflow-macos
#   Downloading tensorflow_macos-2.16.2-cp312-cp312-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Collecting tensorflow==2.16.2 (from tensorflow-macos)
#   Downloading tensorflow-2.16.2-cp312-cp312-macosx_12_0_arm64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.5.5)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.11.0)
# Collecting libclang>=13.0.0 (from tensorflow==2.16.2->tensorflow-macos)
#   Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting ml-dtypes~=0.3.1 (from tensorflow==2.16.2->tensorflow-macos)
#   Downloading ml_dtypes-0.3.2-cp312-cp312-macosx_10_9_universal2.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.4.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.32.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.62.2)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow==2.16.2->tensorflow-macos)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: keras>=3.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (3.7.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorflow==2.16.2->tensorflow-macos) (1.26.4)
# Requirement already satisfied: rich in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (13.3.5)
# Requirement already satisfied: namex in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.0.8)
# Requirement already satisfied: optree in /opt/anaconda3/lib/python3.12/site-packages (from keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow==2.16.2->tensorflow-macos) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow==2.16.2->tensorflow-macos) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.0.0->tensorflow==2.16.2->tensorflow-macos) (0.1.0)
# Downloading tensorflow_macos-2.16.2-cp312-cp312-macosx_12_0_arm64.whl (2.1 kB)
# Downloading tensorflow-2.16.2-cp312-cp312-macosx_12_0_arm64.whl (227.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 MB 1.3 MB/s eta 0:00:0000:0100:04m
# Downloading libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 1.8 MB/s eta 0:00:0000:0100:010m
# Downloading ml_dtypes-0.3.2-cp312-cp312-macosx_10_9_universal2.whl (393 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.6/393.6 kB 2.3 MB/s eta 0:00:0000:0100:01
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 2.2 MB/s eta 0:00:0000:0100:01
# Installing collected packages: libclang, ml-dtypes, tensorboard, tensorflow, tensorflow-macos
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml_dtypes 0.4.0
#     Uninstalling ml_dtypes-0.4.0:
#       Successfully uninstalled ml_dtypes-0.4.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.17.1
#     Uninstalling tensorboard-2.17.1:
#       Successfully uninstalled tensorboard-2.17.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.17.0
#     Uninstalling tensorflow-2.17.0:
#       Successfully uninstalled tensorflow-2.17.0
# Successfully installed libclang-18.1.1 ml-dtypes-0.3.2 tensorboard-2.16.2 tensorflow-2.16.2 tensorflow-macos-2.16.2

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.16.2
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /opt/anaconda3/lib/python3.12/site-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, libclang, ml-dtypes, numpy, opt-einsum, packaging, protobuf, requests, setuptools, six, tensorboard, termcolor, typing-extensions, wrapt
# Required-by: tensorflow-macos

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.16.2

# %%
pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.16.2
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /opt/anaconda3/lib/python3.12/site-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, libclang, ml-dtypes, numpy, opt-einsum, packaging, protobuf, requests, setuptools, six, tensorboard, termcolor, typing-extensions, wrapt
# Required-by: tensorflow-macos
# Note: you may need to restart the kernel to use updated packages.

# %%
# !which python
# Out:
# /opt/anaconda3/bin/python

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
#import tensorflow as tf
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler

# %%
# reading the pizza sales dataset
sales = pd.read_excel("Pizza_Sale.xlsx")
sales.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity           order_date  \
# 0         1         1     hawaiian_m         1  2015-01-01 00:00:00
# 1         2         2  classic_dlx_m         1  2015-01-01 00:00:00
# 2         3         2  five_cheese_l         1  2015-01-01 00:00:00
# 3         4         2    ital_supr_l         1  2015-01-01 00:00:00
# 4         5         2     mexicana_m         1  2015-01-01 00:00:00
#
#   order_time  unit_price  total_price pizza_size pizza_category  \
# 0   11:38:36       13.25        13.25          M        Classic
# 1   11:57:40       16.00        16.00          M        Classic
# 2   11:57:40       18.50        18.50          L         Veggie
# 3   11:57:40       20.75        20.75          L        Supreme
# 4   11:57:40       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name
# 0         The Hawaiian Pizza
# 1   The Classic Deluxe Pizza
# 2      The Five Cheese Pizza
# 3  The Italian Supreme Pizza
# 4         The Mexicana Pizza

# %%
sales.shape
# Out:
# (48620, 12)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48604 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48613 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48597 non-null  object
#  10  pizza_ingredients  48607 non-null  object
#  11  pizza_name         48613 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
# converting order date and time to datetime fromat
sales['order_date'] = pd.to_datetime(sales['order_date'], format='mixed')
sales['order_time'] = pd.to_datetime(sales['order_time'], format='%H:%M:%S').dt.time
sales.head()
# Out:
#    pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0         1         1     hawaiian_m         1 2015-01-01   11:38:36
# 1         2         2  classic_dlx_m         1 2015-01-01   11:57:40
# 2         3         2  five_cheese_l         1 2015-01-01   11:57:40
# 3         4         2    ital_supr_l         1 2015-01-01   11:57:40
# 4         5         2     mexicana_m         1 2015-01-01   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name
# 0         The Hawaiian Pizza
# 1   The Classic Deluxe Pizza
# 2      The Five Cheese Pizza
# 3  The Italian Supreme Pizza
# 4         The Mexicana Pizza

# %%
# Checking null values 
sales.isna().sum()
# Out:
# pizza_id              0
# order_id              0
# pizza_name_id        16
# quantity              0
# order_date            0
# order_time            0
# unit_price            0
# total_price           7
# pizza_size            0
# pizza_category       23
# pizza_ingredients    13
# pizza_name            7
# dtype: int64

# %%
# dropping null values
sales.dropna(inplace=True)

# %%
sales.isna().sum()
# Out:
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
# Checking duplicates
sales.duplicated().sum()
# Out:
# 0

# %%
# checking orderdate type
sales['order_date'].head()
# Out:
# 0   2015-01-01
# 1   2015-01-01
# 2   2015-01-01
# 3   2015-01-01
# 4   2015-01-01
# Name: order_date, dtype: datetime64[ns]

# %%
sales.describe()
# Out:
#            pizza_id      order_id      quantity  \
# count  48554.000000  48554.000000  48554.000000
# mean   24342.866458  10715.733081      1.019648
# min        1.000000      1.000000      1.000000
# 25%    12205.250000   5360.250000      1.000000
# 50%    24343.500000  10702.000000      1.000000
# 75%    36481.750000  16107.750000      1.000000
# max    48620.000000  21350.000000      4.000000
# std    14017.563232   6172.205962      0.143172
#
#                           order_date    unit_price   total_price
# count                          48554  48554.000000  48554.000000
# mean   2015-06-29 00:59:45.616015104     16.493957     16.821744
# min              2015-01-01 00:00:00      9.750000      9.750000
# 25%              2015-03-30 00:00:00     12.750000     12.750000
# 50%              2015-06-28 00:00:00     16.500000     16.500000
# 75%              2015-09-29 00:00:00     20.250000     20.500000
# max              2015-12-31 00:00:00     35.950000     83.000000
# std                              NaN      3.621876      4.438471

# %%
# Checking unique values in each column
sales.nunique()
# Out:
# pizza_id             48554
# order_id             21326
# pizza_name_id           91
# quantity                 4
# order_date             358
# order_time           16368
# unit_price              25
# total_price             56
# pizza_size               5
# pizza_category           4
# pizza_ingredients       32
# pizza_name              32
# dtype: int64

# %%
Exploratory Data Analysis (EDA)

# %%
Daily sales trend over time

# %%
daily_sales = sales.groupby('order_date').agg({'quantity': 'sum'})

# Create the plot
plt.figure(figsize=(18, 6))
plt.plot(daily_sales.index, daily_sales.values)
plt.xlabel('Order Date')
plt.ylabel('Quantity Sold')
plt.title('Quantity Sold Over Time')
plt.grid(True)
plt.show()

# %%
Top Selling Pizzas

# %%
# Group by pizza and calculate total sales
top_pizzas = sales.groupby('pizza_name').agg({'quantity': 'sum'}).sort_values(by='quantity', ascending=False)

# Plot top-selling pizzas
plt.figure(figsize=(12, 6))
sns.barplot(x=top_pizzas['quantity'].head(10), y=top_pizzas.head(10).index)
plt.title('Top 10 Selling Pizzas')
plt.xlabel('Quantity Sold')
plt.ylabel('Pizza Name')
plt.show()

# %%
Sales by day of week

# %%
# Add a day of the week column
sales['day_of_week'] = sales['order_date'].dt.day_name()

# Group by day of the week
sales_by_day = sales.groupby('day_of_week').agg({'quantity': 'sum'}).reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
)

# Plot sales by day of the week
plt.figure(figsize=(10, 6))
sns.barplot(x=sales_by_day.index, y=sales_by_day['quantity'], palette="viridis")
plt.title('Total Sales by Day of the Week', fontsize=14)
plt.xlabel('Day of the Week', fontsize=12)
plt.ylabel('Quantity Sold', fontsize=12)
plt.xticks(rotation=45)
plt.grid(alpha=0.3)
plt.show()

# %%
Sales By Month

# %%
# Add a month column
sales['month'] = sales['order_date'].dt.month_name()

# Group by month
sales_by_month = sales.groupby('month').agg({'quantity': 'sum'}).reindex(
    ['January', 'February', 'March', 'April', 'May', 'June', 
     'July', 'August', 'September', 'October', 'November', 'December']
)

# Plot sales by month
plt.figure(figsize=(10, 6))
sns.barplot(x=sales_by_month.index, y=sales_by_month['quantity'], palette="coolwarm")
plt.title('Total Sales by Month', fontsize=14)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Quantity Sold', fontsize=12)
plt.xticks(rotation=45)
plt.grid(alpha=0.3)
plt.show()

# %%
Peak selling hours in a day

# %%
# Extract hour from order time
sales['hour'] = pd.to_datetime(sales['order_time'], format='%H:%M:%S').dt.hour

# Group by hour
sales_by_hour = sales.groupby('hour').agg({'quantity': 'sum'})

# Plot sales by hour
plt.figure(figsize=(12, 6))
sns.lineplot(x=sales_by_hour.index, y=sales_by_hour['quantity'], marker='o', linestyle='-', color='purple')
plt.title('Total Sales by Hour of the Day', fontsize=14)
plt.xlabel('Hour of the Day', fontsize=12)
plt.ylabel('Quantity Sold', fontsize=12)
plt.grid(alpha=0.3)
plt.xticks(range(0, 24))
plt.show()

# %%
Checking Outliers

# %%
# Plot to check for outliers
plt.figure(figsize=(10, 5))
sns.boxplot(sales['quantity'])
plt.title('Outlier Detection in Quantity Sold')
plt.show()

# %%
# Remove extreme outliers if necessary
sales = sales[sales['quantity'] < sales['quantity'].quantile(0.99)]

# %%
The 99th percentile typically excludes the top 1% of values, which are often extreme outliers in large dataset

# %%
# Plot to check for outliers
plt.figure(figsize=(10, 5))
sns.boxplot(sales['quantity'])
plt.title('Outlier Detection in Quantity Sold')
plt.show()

# %%
Stationarity Check

# %%
# Using  Augmented Dickey-Fuller test to check stationarity

# H0: it is not stationary
# H1: it is stationary

def adf_test(sales):
  result = adfuller(sales)
  print('ADF Statistic: %f' % result[0])
  print('p-value: %f' % result[1])
  print(f'# Lags used: {result[2]}')
  print(f'No of observations used: {result[3]}')
  if result[1] <= 0.05:
    print('we reject the null hypothesis, The series is stationary')
  else:
    print('Not enough statistical evidence to reject null hypothesis, The series is not stationary')

# %%
adf_test(daily_sales)
# Out:
# ADF Statistic: -4.919389
# p-value: 0.000032
# # Lags used: 15
# No of observations used: 342
# we reject the null hypothesis, The series is stationary

# %%
Autocorrelation and partial Autocorrelation
Autocorrelation Function (ACF):

The ACF plot shows the correlation of the series with its lags. Use the ACF to identify q (the number of lagged forecast errors in the ARIMA model). Look for the point where the ACF plot cuts off (significant lags end abruptly).

Partial Autocorrelation Function (PACF):

The PACF plot shows the correlation of the series with its lags after removing the effects of intermediate lags. Use the PACF to identify p (the number of lagged terms in the ARIMA model). Look for the point where the PACF plot cuts off.

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)

# Acf plot
fig = plot_acf(daily_sales, lags=40, ax=ax1)
ax2 = fig.add_subplot(212)

# pacf plot 
fig = plot_pacf(daily_sales, lags=40, ax=ax2)

# %%
ACF Plot:

The ACF cuts off sharply after lag 2, indicating that the moving average component q=2. PACF Plot:

The PACF cuts off sharply after lag 1, indicating that the autoregressive component p=1.

# %%
Sales Prediction

# %%
# Predicting sales of pizzas for next 7  days using ARIMA, SARIMA, Prophet, LSTM 
# choosing best model base on MAPE score(mean_absolute_percentage_error)

# %%
data = sales.groupby(['order_date', 'pizza_name'])['quantity'].sum().unstack().fillna(0)
data.head()
# Out:
# pizza_name  The Barbecue Chicken Pizza  The Big Meat Pizza  \
# order_date
# 2015-01-01                        11.0                 5.0
# 2015-01-02                        12.0                 5.0
# 2015-01-03                         2.0                 3.0
# 2015-01-04                         2.0                 3.0
# 2015-01-05                         6.0                 1.0
#
# pizza_name  The Brie Carre Pizza  The Calabrese Pizza  \
# order_date
# 2015-01-01                   0.0                  1.0
# 2015-01-02                   3.0                  7.0
# 2015-01-03                   1.0                  1.0
# 2015-01-04                   0.0                  2.0
# 2015-01-05                   1.0                  4.0
#
# pizza_name  The California Chicken Pizza  The Chicken Alfredo Pizza  \
# order_date
# 2015-01-01                           4.0                        2.0
# 2015-01-02                          15.0                        3.0
# 2015-01-03                           6.0                        0.0
# 2015-01-04                           3.0                        3.0
# 2015-01-05                          11.0                        2.0
#
# pizza_name  The Chicken Pesto Pizza  The Classic Deluxe Pizza  \
# order_date
# 2015-01-01                      4.0                      10.0
# 2015-01-02                      2.0                      13.0
# 2015-01-03                      1.0                       4.0
# 2015-01-04                      2.0                       8.0
# 2015-01-05                      3.0                       9.0
#
# pizza_name  The Five Cheese Pizza  The Four Cheese Pizza  ...  \
# order_date                                                ...
# 2015-01-01                    6.0                    5.0  ...
# 2015-01-02                    5.0                    6.0  ...
# 2015-01-03                    5.0                    4.0  ...
# 2015-01-04                    7.0                    6.0  ...
# 2015-01-05                    4.0                    4.0  ...
#
# pizza_name  The Prosciutto and Arugula Pizza  The Sicilian Pizza  \
# order_date
# 2015-01-01                               4.0                 4.0
# 2015-01-02                               6.0                 5.0
# 2015-01-03                               1.0                 2.0
# 2015-01-04                               4.0                 8.0
# 2015-01-05                               5.0                 5.0
#
# pizza_name  The Soppressata Pizza  The Southwest Chicken Pizza  \
# order_date
# 2015-01-01                    0.0                          7.0
# 2015-01-02                    3.0                          9.0
# 2015-01-03                    0.0                          9.0
# 2015-01-04                    6.0                         10.0
# 2015-01-05                    0.0                          6.0
#
# pizza_name  The Spicy Italian Pizza  The Spinach Pesto Pizza  \
# order_date
# 2015-01-01                      5.0                      2.0
# 2015-01-02                      9.0                      5.0
# 2015-01-03                      4.0                      3.0
# 2015-01-04                      4.0                      4.0
# 2015-01-05                      5.0                      2.0
#
# pizza_name  The Spinach Supreme Pizza  The Spinach and Feta Pizza  \
# order_date
# 2015-01-01                        5.0                         2.0
# 2015-01-02                        3.0                         4.0
# 2015-01-03                        0.0                         5.0
# 2015-01-04                        6.0                         1.0
# 2015-01-05                        4.0                         5.0
#
# pizza_name  The Thai Chicken Pizza  The Vegetables + Vegetables Pizza
# order_date
# 2015-01-01                     7.0                                3.0
# 2015-01-02                     8.0                                1.0
# 2015-01-03                     4.0                                6.0
# 2015-01-04                     3.0                                5.0
# 2015-01-05                    10.0                                6.0
#
# [5 rows x 32 columns]

# %%
one_pizza = data['The Barbecue Chicken Pizza']

# %%
# Train-Test Split
train = one_pizza[:-30]  # Use all but the last 30 days for training
test = one_pizza[-30:]   # Use the last 30 days for testing

# %%
train.isna().sum()
# Out:
# 0

# %%
train = train.fillna(train.median())

# %%
ARIMA Model

# %%
print(train.index)
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-10',
#                ...
#                '2015-11-20', '2015-11-21', '2015-11-22', '2015-11-23',
#                '2015-11-24', '2015-11-25', '2015-11-26', '2015-11-27',
#                '2015-11-28', '2015-11-29'],
#               dtype='datetime64[ns]', name='order_date', length=328, freq=None)

# %%
train.index = pd.to_datetime(train.index)
train = train.asfreq('D')  # 'D' for daily, adjust based on your data's frequency

# %%
# Fit ARIMA model (order=(1, 1, 1) as a starting point; optimize based on AIC/BIC)
arima_model = ARIMA(train, order=(1, 0, 2))
arima_result = arima_model.fit()

# Forecast
arima_forecast = arima_result.forecast(steps=len(test))

# Evaluate ARIMA Model
arima_mape = mean_absolute_percentage_error(test, arima_forecast)

print("ARIMA Model MAPE:", arima_mape)
# Out:
# ARIMA Model MAPE: 0.49021344525474375

# %%
# Plot Actual vs Predicted
plt.figure(figsize=(10, 5))
plt.plot(test.index, test, label='Actual', color='blue')
plt.plot(test.index, arima_forecast, label='ARIMA Predicted', linestyle='--', color='orange')
plt.title('ARIMA Model: Actual vs Predicted')
plt.xlabel('Date')
plt.ylabel('Quantity Sold')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %%
ARIMA model is appearing to predict a flat trend, not capturing the variability in actual sales

# %%
SARIMA Model

# %%
# Fit SARIMA model (seasonal_order=(1, 1, 1, 7) for weekly seasonality; adjust as needed)
sarima_model = SARIMAX(train, order=(1, 1, 1), seasonal_order=(1, 1, 1, 7))
sarima_result = sarima_model.fit()

# Forecast
sarima_forecast = sarima_result.forecast(steps=len(test))

# Evaluate SARIMA Model
sarima_mape = mean_absolute_percentage_error(test, sarima_forecast)

print("SARIMA Model MAPE:", sarima_mape)
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.63253D+00    |proj g|=  1.11815D-01
#
# At iterate    5    f=  2.39079D+00    |proj g|=  2.14185D-02
#
# At iterate   10    f=  2.37308D+00    |proj g|=  2.28764D-03
#
# At iterate   15    f=  2.37177D+00    |proj g|=  3.43023D-03
#
# At iterate   20    f=  2.37162D+00    |proj g|=  6.84461D-04
#
# At iterate   25    f=  2.37160D+00    |proj g|=  5.99084D-04
#
# At iterate   30    f=  2.37160D+00    |proj g|=  1.30734D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     33     40      1     0     0   2.337D-04   2.372D+00
#   F =   2.3716027765561822
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# SARIMA Model MAPE: 0.4439493435625872

# %%
# Plot Actual vs Predicted
plt.figure(figsize=(10, 5))
plt.plot(test.index, test, label='Actual', color='blue')
plt.plot(test.index, sarima_forecast, label='SARIMA Predicted', linestyle='--', color='orange')
plt.title('SARIMA Model: Actual vs Predicted')
plt.xlabel('Date')
plt.ylabel('Quantity Sold')
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %%
SARIMA predictions show periodic peaks and dips, indicating it captures seasonality better than ARIMA.
However, there’s still a lag in capturing sudden changes in sales

# %%
Prophet Model

# %%
# !conda install -c conda-forge prophet -y
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - prophet
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     clang-14.0.6               |       hce30654_0         127 KB  conda-forge
#     clang-14-14.0.6            |default_h81a5282_0         961 KB  conda-forge
#     clang_osx-arm64-14.0.6     |       h15773ab_6          20 KB  conda-forge
#     clangxx-14.0.6             |default_hb7ecf47_0         127 KB  conda-forge
#     clangxx_osx-arm64-14.0.6   |       he29aa18_6          19 KB  conda-forge
#     cmdstan-2.31.0             |       hd06e7c4_0        39.0 MB  conda-forge
#     cmdstanpy-1.2.4            |     pyhd8ed1ab_0          69 KB  conda-forge
#     compiler-rt-14.0.6         |       h30b49de_0          83 KB  conda-forge
#     compiler-rt_osx-arm64-14.0.6|       h48302dc_0        15.1 MB  conda-forge
#     holidays-0.61              |     pyhd8ed1ab_0         400 KB  conda-forge
#     importlib_resources-6.4.5  |     pyhd8ed1ab_0          32 KB  conda-forge
#     libclang-cpp14-14.0.6      |default_h81a5282_0        13.1 MB  conda-forge
#     llvm-tools-14.0.6          |       hfd8c8a6_3        10.4 MB
#     make-4.4.1                 |       hc9fafa5_2         268 KB  conda-forge
#     prophet-1.1.5              |  py312h48ca7d4_0         893 KB
#     stanio-0.5.1               |     pyhd8ed1ab_0          13 KB  conda-forge
#     tbb-devel-2021.8.0         |       h48ca7d4_0         1.1 MB
#     ------------------------------------------------------------
#                                            Total:        81.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   clang              conda-forge/osx-arm64::clang-14.0.6-hce30654_0
#   clang-14           conda-forge/osx-arm64::clang-14-14.0.6-default_h81a5282_0
#   clang_osx-arm64    conda-forge/osx-arm64::clang_osx-arm64-14.0.6-h15773ab_6
#   clangxx            conda-forge/osx-arm64::clangxx-14.0.6-default_hb7ecf47_0
#   clangxx_osx-arm64  conda-forge/osx-arm64::clangxx_osx-arm64-14.0.6-he29aa18_6
#   cmdstan            conda-forge/osx-arm64::cmdstan-2.31.0-hd06e7c4_0
#   cmdstanpy          conda-forge/noarch::cmdstanpy-1.2.4-pyhd8ed1ab_0
#   compiler-rt        conda-forge/osx-arm64::compiler-rt-14.0.6-h30b49de_0
#   compiler-rt_osx-a~ conda-forge/noarch::compiler-rt_osx-arm64-14.0.6-h48302dc_0
#   holidays           conda-forge/noarch::holidays-0.61-pyhd8ed1ab_0
#   importlib_resourc~ conda-forge/noarch::importlib_resources-6.4.5-pyhd8ed1ab_0
#   libclang-cpp14     conda-forge/osx-arm64::libclang-cpp14-14.0.6-default_h81a5282_0
#   llvm-tools         pkgs/main/osx-arm64::llvm-tools-14.0.6-hfd8c8a6_3
#   make               conda-forge/osx-arm64::make-4.4.1-hc9fafa5_2
#   prophet            pkgs/main/osx-arm64::prophet-1.1.5-py312h48ca7d4_0
#   stanio             conda-forge/noarch::stanio-0.5.1-pyhd8ed1ab_0
#   tbb-devel          pkgs/main/osx-arm64::tbb-devel-2021.8.0-h48ca7d4_0
#
#
#
# Downloading and Extracting Packages:
# cmdstan-2.31.0       | 39.0 MB   |                                       |   0%
# compiler-rt_osx-arm6 | 15.1 MB   |                                       |   0%
#
# libclang-cpp14-14.0. | 13.1 MB   |                                       |   0%
#
#
# llvm-tools-14.0.6    | 10.4 MB   |                                       |   0%
#
#
#
# tbb-devel-2021.8.0   | 1.1 MB    |                                       |   0%
#
#
#
#
# clang-14-14.0.6      | 961 KB    |                                       |   0%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    |                                       |   0%
#
#
#
#
#
#
# holidays-0.61        | 400 KB    |                                       |   0%
#
#
#
#
#
#
#
# make-4.4.1           | 268 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# clangxx-14.0.6       | 127 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# clang-14.0.6         | 127 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# compiler-rt-14.0.6   | 83 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# cmdstanpy-1.2.4      | 69 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# importlib_resources- | 32 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# clang_osx-arm64-14.0 | 20 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# clangxx_osx-arm64-14 | 19 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# stanio-0.5.1         | 13 KB     |                                       |   0%
#
# libclang-cpp14-14.0. | 13.1 MB   |                                       |   0%
# compiler-rt_osx-arm6 | 15.1 MB   |                                       |   0%
#
#
#
# tbb-devel-2021.8.0   | 1.1 MB    | 5                                     |   1%
# compiler-rt_osx-arm6 | 15.1 MB   | 1                                     |   0%
#
#
#
# tbb-devel-2021.8.0   | 1.1 MB    | #6                                    |   4%
# compiler-rt_osx-arm6 | 15.1 MB   | 2                                     |   1%
#
#
#
# tbb-devel-2021.8.0   | 1.1 MB    | ###2                                  |   9%
#
# libclang-cpp14-14.0. | 13.1 MB   | 3                                     |   1%
#
# cmdstan-2.31.0       | 39.0 MB   |                                       |   0%
#
#
#
# cmdstan-2.31.0       | 39.0 MB   |                                       |   0%
# compiler-rt_osx-arm6 | 15.1 MB   | 3                                     |   1%
#
#
#
# tbb-devel-2021.8.0   | 1.1 MB    | ######                                |  16%
#
#
# llvm-tools-14.0.6    | 10.4 MB   |                                       |   0%
# compiler-rt_osx-arm6 | 15.1 MB   | 5                                     |   1%
#
#
#
# tbb-devel-2021.8.0   | 1.1 MB    | #######6                              |  21%
#
# libclang-cpp14-14.0. | 13.1 MB   | 7                                     |   2%
#
# libclang-cpp14-14.0. | 13.1 MB   | #1                                    |   3%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | 3                                     |   1%
# compiler-rt_osx-arm6 | 15.1 MB   | 6                                     |   2%
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | 1                                     |   0%
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | 1                                     |   0%
# compiler-rt_osx-arm6 | 15.1 MB   | #1                                    |   3%
#
#
#
# tbb-devel-2021.8.0   | 1.1 MB    | ################4                     |  44%
# compiler-rt_osx-arm6 | 15.1 MB   | #2                                    |   3%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | 4                                     |   1%
#
#
#
# tbb-devel-2021.8.0   | 1.1 MB    | ##################                    |  49%
#
# libclang-cpp14-14.0. | 13.1 MB   | #5                                    |   4%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | 7                                     |   2%
#
# libclang-cpp14-14.0. | 13.1 MB   | #7                                    |   5%
#
# libclang-cpp14-14.0. | 13.1 MB   | #8                                    |   5%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##1                                   |   6%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##2                                   |   6%
# compiler-rt_osx-arm6 | 15.1 MB   | #3                                    |   4%
# compiler-rt_osx-arm6 | 15.1 MB   | #4                                    |   4%
# cmdstan-2.31.0       | 39.0 MB   | 2                                     |   1%
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | 3                                     |   1%
#
#
#
# tbb-devel-2021.8.0   | 1.1 MB    | #####################3                |  58%
# compiler-rt_osx-arm6 | 15.1 MB   | #9                                    |   5%
#
#
#
# tbb-devel-2021.8.0   | 1.1 MB    | #######################5              |  64%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##4                                   |   7%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##7                                   |   8%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | 8                                     |   2%
# compiler-rt_osx-arm6 | 15.1 MB   | ##1                                   |   6%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###9                                  |  11%
# cmdstan-2.31.0       | 39.0 MB   | 4                                     |   1%
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | 6                                     |   2%
# compiler-rt_osx-arm6 | 15.1 MB   | ##9                                   |   8%
#
#
#
# tbb-devel-2021.8.0   | 1.1 MB    | ###############################7      |  86%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | 9                                     |   3%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #1                                    |   3%
# compiler-rt_osx-arm6 | 15.1 MB   | ###1                                  |   9%
# compiler-rt_osx-arm6 | 15.1 MB   | ###3                                  |   9%
#
# libclang-cpp14-14.0. | 13.1 MB   | ####4                                 |  12%
# compiler-rt_osx-arm6 | 15.1 MB   | ###4                                  |   9%
# compiler-rt_osx-arm6 | 15.1 MB   | ###6                                  |  10%
# cmdstan-2.31.0       | 39.0 MB   | 7                                     |   2%
#
#
#
# tbb-devel-2021.8.0   | 1.1 MB    | ##################################4   |  93%
#
# libclang-cpp14-14.0. | 13.1 MB   | ####8                                 |  13%
# compiler-rt_osx-arm6 | 15.1 MB   | ###8                                  |  10%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #2                                    |   3%
# compiler-rt_osx-arm6 | 15.1 MB   | ###9                                  |  11%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #4                                    |   4%
#
# libclang-cpp14-14.0. | 13.1 MB   | #####                                 |  14%
# compiler-rt_osx-arm6 | 15.1 MB   | ####                                  |  11%
# compiler-rt_osx-arm6 | 15.1 MB   | ####1                                 |  11%
#
# libclang-cpp14-14.0. | 13.1 MB   | #####3                                |  14%
# compiler-rt_osx-arm6 | 15.1 MB   | ####6                                 |  13%
#
# cmdstan-2.31.0       | 39.0 MB   | 8                                     |   2%
#
# libclang-cpp14-14.0. | 13.1 MB   | ######                                |  16%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #6                                    |   4%
#
# libclang-cpp14-14.0. | 13.1 MB   | ######2                               |  17%
# cmdstan-2.31.0       | 39.0 MB   | 9                                     |   2%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #7                                    |   5%
#
# libclang-cpp14-14.0. | 13.1 MB   | ######5                               |  18%
#
#
# cmdstan-2.31.0       | 39.0 MB   | 9                                     |   3%
# compiler-rt_osx-arm6 | 15.1 MB   | #####                                 |  14%
#
# libclang-cpp14-14.0. | 13.1 MB   | ######9                               |  19%
#
#
#
# tbb-devel-2021.8.0   | 1.1 MB    | ####################################1 |  98%
# compiler-rt_osx-arm6 | 15.1 MB   | #####1                                |  14%
#
#
#
# tbb-devel-2021.8.0   | 1.1 MB    | ##################################### | 100%
#
# cmdstan-2.31.0       | 39.0 MB   | #                                     |   3%
#
#
#
# tbb-devel-2021.8.0   | 1.1 MB    | ##################################### | 100%
#
# libclang-cpp14-14.0. | 13.1 MB   | #######4                              |  20%
# compiler-rt_osx-arm6 | 15.1 MB   | #####2                                |  14%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #                                     |   3%
# compiler-rt_osx-arm6 | 15.1 MB   | #####4                                |  15%
#
# libclang-cpp14-14.0. | 13.1 MB   | #######6                              |  21%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##3                                   |   6%
#
# cmdstan-2.31.0       | 39.0 MB   | #                                     |   3%
#
#
#
#
# clang-14-14.0.6      | 961 KB    | 6                                     |   2%
# compiler-rt_osx-arm6 | 15.1 MB   | #####5                                |  15%
#
#
#
#
# clang-14-14.0.6      | 961 KB    | ##4                                   |   7%
#
#
#
#
# clang-14-14.0.6      | 961 KB    | ####3                                 |  12%
# compiler-rt_osx-arm6 | 15.1 MB   | #####5                                |  15%
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | #                                     |   3%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##4                                   |   7%
# compiler-rt_osx-arm6 | 15.1 MB   | #####7                                |  15%
#
# libclang-cpp14-14.0. | 13.1 MB   | ########                              |  22%
# cmdstan-2.31.0       | 39.0 MB   | #1                                    |   3%
#
#
#
#
# clang-14-14.0.6      | 961 KB    | ########6                             |  23%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##5                                   |   7%
#
# libclang-cpp14-14.0. | 13.1 MB   | ########1                             |  22%
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | #1                                    |   3%
# compiler-rt_osx-arm6 | 15.1 MB   | #####8                                |  16%
#
#
#
#
# clang-14-14.0.6      | 961 KB    | ###########6                          |  32%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##6                                   |   7%
#
#
#
#
# clang-14-14.0.6      | 961 KB    | #############5                        |  37%
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | #1                                    |   3%
# compiler-rt_osx-arm6 | 15.1 MB   | #####9                                |  16%
#
# libclang-cpp14-14.0. | 13.1 MB   | ########3                             |  22%
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | #1                                    |   3%
#
# libclang-cpp14-14.0. | 13.1 MB   | ########3                             |  23%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##6                                   |   7%
# cmdstan-2.31.0       | 39.0 MB   | #1                                    |   3%
#
# libclang-cpp14-14.0. | 13.1 MB   | ########5                             |  23%
#
#
#
#
# clang-14-14.0.6      | 961 KB    | ######################7               |  62%
# compiler-rt_osx-arm6 | 15.1 MB   | ######                                |  16%
#
# libclang-cpp14-14.0. | 13.1 MB   | ########6                             |  23%
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | #2                                    |   3%
#
#
#
#
# clang-14-14.0.6      | 961 KB    | ###########################7          |  75%
# compiler-rt_osx-arm6 | 15.1 MB   | ######                                |  16%
#
#
#
#
# clang-14-14.0.6      | 961 KB    | ##############################7       |  83%
# cmdstan-2.31.0       | 39.0 MB   | #2                                    |   3%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##7                                   |   7%
#
#
#
#
# clang-14-14.0.6      | 961 KB    | #################################2    |  90%
# compiler-rt_osx-arm6 | 15.1 MB   | ######1                               |  17%
#
# libclang-cpp14-14.0. | 13.1 MB   | ########7                             |  24%
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | #2                                    |   3%
#
# libclang-cpp14-14.0. | 13.1 MB   | ########7                             |  24%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##8                                   |   8%
# compiler-rt_osx-arm6 | 15.1 MB   | ######2                               |  17%
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | #2                                    |   3%
#
# libclang-cpp14-14.0. | 13.1 MB   | ########9                             |  24%
# compiler-rt_osx-arm6 | 15.1 MB   | ######2                               |  17%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #2                                    |   3%
#
# libclang-cpp14-14.0. | 13.1 MB   | #########1                            |  25%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###                                   |   8%
# compiler-rt_osx-arm6 | 15.1 MB   | ######4                               |  17%
#
#
#
#
# clang-14-14.0.6      | 961 KB    | ##################################### | 100%
#
# cmdstan-2.31.0       | 39.0 MB   | #3                                    |   4%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###2                                  |   9%
# compiler-rt_osx-arm6 | 15.1 MB   | ######5                               |  18%
#
# cmdstan-2.31.0       | 39.0 MB   | #3                                    |   4%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###3                                  |   9%
#
# libclang-cpp14-14.0. | 13.1 MB   | #########8                            |  27%
# cmdstan-2.31.0       | 39.0 MB   | #3                                    |   4%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##########                            |  27%
# compiler-rt_osx-arm6 | 15.1 MB   | ######7                               |  18%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###4                                  |   9%
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | #4                                    |   4%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##########2                           |  28%
# compiler-rt_osx-arm6 | 15.1 MB   | ######8                               |  19%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | ##6                                   |   7%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###5                                  |  10%
#
# cmdstan-2.31.0       | 39.0 MB   | #4                                    |   4%
# compiler-rt_osx-arm6 | 15.1 MB   | ######9                               |  19%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | ####6                                 |  13%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##########6                           |  29%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #4                                    |   4%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##########7                           |  29%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | #####9                                |  16%
# compiler-rt_osx-arm6 | 15.1 MB   | #######                               |  19%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###7                                  |  10%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##########8                           |  29%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | #######2                              |  20%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #5                                    |   4%
# compiler-rt_osx-arm6 | 15.1 MB   | #######                               |  19%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | ########6                             |  23%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##########9                           |  30%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###8                                  |  10%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | ##########6                           |  29%
# cmdstan-2.31.0       | 39.0 MB   | #5                                    |   4%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###########1                          |  30%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###9                                  |  11%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | ############6                         |  34%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###########3                          |  31%
# cmdstan-2.31.0       | 39.0 MB   | #5                                    |   4%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | #############9                        |  38%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###########4                          |  31%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ####                                  |  11%
# cmdstan-2.31.0       | 39.0 MB   | #6                                    |   4%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###########6                          |  31%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | ###############9                      |  43%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ####                                  |  11%
# compiler-rt_osx-arm6 | 15.1 MB   | #######3                              |  20%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###########7                          |  32%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | #################2                    |  47%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ####1                                 |  11%
#
# cmdstan-2.31.0       | 39.0 MB   | #6                                    |   4%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | ##################5                   |  50%
# compiler-rt_osx-arm6 | 15.1 MB   | #######4                              |  20%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ####2                                 |  11%
#
# libclang-cpp14-14.0. | 13.1 MB   | ############                          |  32%
# cmdstan-2.31.0       | 39.0 MB   | #6                                    |   4%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | ###################8                  |  54%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ####2                                 |  12%
# compiler-rt_osx-arm6 | 15.1 MB   | #######5                              |  20%
#
# libclang-cpp14-14.0. | 13.1 MB   | ############1                         |  33%
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | #6                                    |   5%
#
# libclang-cpp14-14.0. | 13.1 MB   | ############2                         |  33%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | #######################2              |  63%
# compiler-rt_osx-arm6 | 15.1 MB   | #######6                              |  21%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ####3                                 |  12%
#
# cmdstan-2.31.0       | 39.0 MB   | #6                                    |   5%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | ########################5             |  66%
# compiler-rt_osx-arm6 | 15.1 MB   | #######6                              |  21%
#
# libclang-cpp14-14.0. | 13.1 MB   | ############5                         |  34%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ####4                                 |  12%
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | #7                                    |   5%
#
# libclang-cpp14-14.0. | 13.1 MB   | ############6                         |  34%
# compiler-rt_osx-arm6 | 15.1 MB   | #######7                              |  21%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #7                                    |   5%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | ############################5         |  77%
#
# libclang-cpp14-14.0. | 13.1 MB   | ############8                         |  35%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ####5                                 |  12%
# compiler-rt_osx-arm6 | 15.1 MB   | #######8                              |  21%
#
# libclang-cpp14-14.0. | 13.1 MB   | ############9                         |  35%
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | #7                                    |   5%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ####7                                 |  13%
# compiler-rt_osx-arm6 | 15.1 MB   | #######9                              |  21%
#
# libclang-cpp14-14.0. | 13.1 MB   | #############2                        |  36%
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | #8                                    |   5%
#
# libclang-cpp14-14.0. | 13.1 MB   | #############4                        |  36%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | ###################################8  |  97%
# compiler-rt_osx-arm6 | 15.1 MB   | ########                              |  22%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ####8                                 |  13%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | ##################################### | 100%
#
#
#
#
#
# prophet-1.1.5        | 893 KB    | ##################################### | 100%
#
# cmdstan-2.31.0       | 39.0 MB   | #8                                    |   5%
# compiler-rt_osx-arm6 | 15.1 MB   | ########1                             |  22%
#
# libclang-cpp14-14.0. | 13.1 MB   | #############7                        |  37%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ####9                                 |  13%
# cmdstan-2.31.0       | 39.0 MB   | #8                                    |   5%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #####                                 |  14%
#
#
#
#
#
#
# holidays-0.61        | 400 KB    | #4                                    |   4%
#
# libclang-cpp14-14.0. | 13.1 MB   | #############9                        |  38%
#
#
#
#
#
#
# holidays-0.61        | 400 KB    | ########8                             |  24%
# compiler-rt_osx-arm6 | 15.1 MB   | ########2                             |  22%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##############1                       |  38%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #8                                    |   5%
# compiler-rt_osx-arm6 | 15.1 MB   | ########3                             |  23%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##############3                       |  39%
#
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | #9                                    |   5%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #####2                                |  14%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##############5                       |  39%
# cmdstan-2.31.0       | 39.0 MB   | #9                                    |   5%
#
#
#
#
#
#
# holidays-0.61        | 400 KB    | ######################1               |  60%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##############6                       |  40%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #####3                                |  14%
# cmdstan-2.31.0       | 39.0 MB   | #9                                    |   5%
#
#
#
#
#
#
# holidays-0.61        | 400 KB    | ##########################6           |  72%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##############7                       |  40%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #9                                    |   5%
#
#
#
#
#
#
# holidays-0.61        | 400 KB    | ###############################       |  84%
# compiler-rt_osx-arm6 | 15.1 MB   | ########5                             |  23%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##############9                       |  40%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #9                                    |   5%
#
#
#
#
#
#
# holidays-0.61        | 400 KB    | ###################################5  |  96%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###############                       |  41%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #####4                                |  15%
#
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##                                    |   5%
# compiler-rt_osx-arm6 | 15.1 MB   | ########6                             |  23%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###############2                      |  41%
# compiler-rt_osx-arm6 | 15.1 MB   | ########7                             |  24%
#
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##                                    |   5%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #####5                                |  15%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###############4                      |  42%
# compiler-rt_osx-arm6 | 15.1 MB   | ########8                             |  24%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##                                    |   6%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###############5                      |  42%
#
#
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##                                    |   6%
# compiler-rt_osx-arm6 | 15.1 MB   | ########8                             |  24%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###############7                      |  43%
#
#
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##                                    |   6%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #####8                                |  16%
#
#
#
#
#
#
#
# make-4.4.1           | 268 KB    | ###########                           |  30%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###############8                      |  43%
# compiler-rt_osx-arm6 | 15.1 MB   | ########9                             |  24%
#
#
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##1                                   |   6%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #####8                                |  16%
#
# cmdstan-2.31.0       | 39.0 MB   | ##1                                   |   6%
#
#
#
#
#
#
#
# make-4.4.1           | 268 KB    | ######################1               |  60%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #####9                                |  16%
# compiler-rt_osx-arm6 | 15.1 MB   | #########                             |  24%
#
# libclang-cpp14-14.0. | 13.1 MB   | ################                      |  43%
#
#
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##1                                   |   6%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #####9                                |  16%
#
# libclang-cpp14-14.0. | 13.1 MB   | ################1                     |  44%
#
#
#
#
#
#
#
# make-4.4.1           | 268 KB    | ##############################9       |  84%
# compiler-rt_osx-arm6 | 15.1 MB   | #########                             |  25%
#
#
#
#
#
#
#
# make-4.4.1           | 268 KB    | ###################################3  |  96%
#
# libclang-cpp14-14.0. | 13.1 MB   | ################2                     |  44%
#
#
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##1                                   |   6%
#
#
#
#
#
#
#
# make-4.4.1           | 268 KB    | ##################################### | 100%
# compiler-rt_osx-arm6 | 15.1 MB   | #########1                            |  25%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ######                                |  16%
#
# libclang-cpp14-14.0. | 13.1 MB   | ################3                     |  44%
# cmdstan-2.31.0       | 39.0 MB   | ##1                                   |   6%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ######                                |  16%
# cmdstan-2.31.0       | 39.0 MB   | ##1                                   |   6%
#
# libclang-cpp14-14.0. | 13.1 MB   | ################4                     |  45%
# compiler-rt_osx-arm6 | 15.1 MB   | #########3                            |  25%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##2                                   |   6%
#
# libclang-cpp14-14.0. | 13.1 MB   | ################7                     |  45%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ######3                               |  17%
# compiler-rt_osx-arm6 | 15.1 MB   | #########3                            |  25%
#
# cmdstan-2.31.0       | 39.0 MB   | ##2                                   |   6%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ######4                               |  17%
#
# libclang-cpp14-14.0. | 13.1 MB   | #################                     |  46%
# cmdstan-2.31.0       | 39.0 MB   | ##2                                   |   6%
#
#
#
#
#
#
#
#
# clangxx-14.0.6       | 127 KB    | ####6                                 |  13%
#
# libclang-cpp14-14.0. | 13.1 MB   | #################3                    |  47%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ######5                               |  18%
# compiler-rt_osx-arm6 | 15.1 MB   | #########5                            |  26%
#
#
#
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##3                                   |   6%
#
# libclang-cpp14-14.0. | 13.1 MB   | #################4                    |  47%
# compiler-rt_osx-arm6 | 15.1 MB   | #########6                            |  26%
#
#
#
#
#
#
#
#
# clangxx-14.0.6       | 127 KB    | ################################6     |  88%
#
#
#
#
#
#
#
#
# clangxx-14.0.6       | 127 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# clangxx-14.0.6       | 127 KB    | ##################################### | 100%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ######6                               |  18%
#
# cmdstan-2.31.0       | 39.0 MB   | ##3                                   |   6%
# compiler-rt_osx-arm6 | 15.1 MB   | #########7                            |  26%
#
# libclang-cpp14-14.0. | 13.1 MB   | #################7                    |  48%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##3                                   |   6%
# compiler-rt_osx-arm6 | 15.1 MB   | #########8                            |  26%
#
# libclang-cpp14-14.0. | 13.1 MB   | #################9                    |  48%
#
#
#
#
#
#
#
#
#
# clang-14.0.6         | 127 KB    | ####6                                 |  13%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##################                    |  49%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ######8                               |  19%
# compiler-rt_osx-arm6 | 15.1 MB   | #########8                            |  27%
#
#
#
#
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##3                                   |   6%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##################1                   |  49%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ######9                               |  19%
#
#
#
#
#
#
#
#
#
# clang-14.0.6         | 127 KB    | ###########################9          |  76%
#
#
#
#
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##4                                   |   6%
#
#
#
#
#
#
#
#
#
# clang-14.0.6         | 127 KB    | ##################################### | 100%
# compiler-rt_osx-arm6 | 15.1 MB   | #########9                            |  27%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ######9                               |  19%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##################3                   |  50%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #######                               |  19%
#
# cmdstan-2.31.0       | 39.0 MB   | ##4                                   |   7%
# compiler-rt_osx-arm6 | 15.1 MB   | ##########                            |  27%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #######                               |  19%
#
# cmdstan-2.31.0       | 39.0 MB   | ##4                                   |   7%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #######1                              |  19%
# compiler-rt_osx-arm6 | 15.1 MB   | ##########1                           |  27%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##################7                   |  51%
#
#
#
#
#
#
#
#
#
#
# compiler-rt-14.0.6   | 83 KB     | #######                               |  19%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##4                                   |   7%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##################8                   |  51%
#
#
#
#
#
#
#
#
#
#
# compiler-rt-14.0.6   | 83 KB     | ############################3         |  77%
#
#
#
#
#
#
#
#
#
#
# compiler-rt-14.0.6   | 83 KB     | ##################################### | 100%
# compiler-rt_osx-arm6 | 15.1 MB   | ##########1                           |  28%
#
#
#
#
#
#
#
#
#
#
# compiler-rt-14.0.6   | 83 KB     | ##################################### | 100%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##5                                   |   7%
# compiler-rt_osx-arm6 | 15.1 MB   | ##########2                           |  28%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###################                   |  52%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #######3                              |  20%
# compiler-rt_osx-arm6 | 15.1 MB   | ##########3                           |  28%
#
# cmdstan-2.31.0       | 39.0 MB   | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# cmdstanpy-1.2.4      | 69 KB     | ########5                             |  23%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #######4                              |  20%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###################4                  |  53%
# compiler-rt_osx-arm6 | 15.1 MB   | ##########4                           |  28%
#
#
#
#
#
#
#
#
#
#
#
# cmdstanpy-1.2.4      | 69 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# cmdstanpy-1.2.4      | 69 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##5                                   |   7%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###################6                  |  53%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #######5                              |  20%
# cmdstan-2.31.0       | 39.0 MB   | ##5                                   |   7%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###################8                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
# importlib_resources- | 32 KB     | ##################5                   |  50%
# compiler-rt_osx-arm6 | 15.1 MB   | ##########5                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
# importlib_resources- | 32 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# importlib_resources- | 32 KB     | ##################################### | 100%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #######6                              |  21%
#
# cmdstan-2.31.0       | 39.0 MB   | ##6                                   |   7%
# compiler-rt_osx-arm6 | 15.1 MB   | ##########6                           |  29%
#
# libclang-cpp14-14.0. | 13.1 MB   | ####################2                 |  55%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #######8                              |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
# clang_osx-arm64-14.0 | 20 KB     | #############################5        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
# clang_osx-arm64-14.0 | 20 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# clang_osx-arm64-14.0 | 20 KB     | ##################################### | 100%
# cmdstan-2.31.0       | 39.0 MB   | ##6                                   |   7%
#
# libclang-cpp14-14.0. | 13.1 MB   | ####################4                 |  55%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #######9                              |  21%
#
# libclang-cpp14-14.0. | 13.1 MB   | ####################6                 |  56%
# cmdstan-2.31.0       | 39.0 MB   | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# clangxx_osx-arm64-14 | 19 KB     | ###############################2      |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# clangxx_osx-arm64-14 | 19 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# clangxx_osx-arm64-14 | 19 KB     | ##################################### | 100%
#
# libclang-cpp14-14.0. | 13.1 MB   | ####################8                 |  56%
# compiler-rt_osx-arm6 | 15.1 MB   | ##########8                           |  29%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ########                              |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# stanio-0.5.1         | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# stanio-0.5.1         | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##7                                   |   7%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ########                              |  22%
#
# cmdstan-2.31.0       | 39.0 MB   | ##7                                   |   7%
# compiler-rt_osx-arm6 | 15.1 MB   | ##########9                           |  30%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ########1                             |  22%
#
# libclang-cpp14-14.0. | 13.1 MB   | #####################2                |  57%
# cmdstan-2.31.0       | 39.0 MB   | ##7                                   |   7%
#
# libclang-cpp14-14.0. | 13.1 MB   | #####################4                |  58%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ########2                             |  22%
# cmdstan-2.31.0       | 39.0 MB   | ##7                                   |   8%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ########2                             |  22%
#
# libclang-cpp14-14.0. | 13.1 MB   | #####################6                |  59%
# compiler-rt_osx-arm6 | 15.1 MB   | ###########1                          |  30%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ########3                             |  23%
#
# cmdstan-2.31.0       | 39.0 MB   | ##8                                   |   8%
# compiler-rt_osx-arm6 | 15.1 MB   | ###########2                          |  30%
#
# libclang-cpp14-14.0. | 13.1 MB   | ######################                |  60%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##8                                   |   8%
# compiler-rt_osx-arm6 | 15.1 MB   | ###########3                          |  31%
#
# libclang-cpp14-14.0. | 13.1 MB   | ######################3               |  60%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##8                                   |   8%
# compiler-rt_osx-arm6 | 15.1 MB   | ###########4                          |  31%
#
# cmdstan-2.31.0       | 39.0 MB   | ##9                                   |   8%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ########6                             |  23%
#
# libclang-cpp14-14.0. | 13.1 MB   | ######################7               |  61%
# compiler-rt_osx-arm6 | 15.1 MB   | ###########5                          |  31%
#
# libclang-cpp14-14.0. | 13.1 MB   | ######################9               |  62%
# cmdstan-2.31.0       | 39.0 MB   | ##9                                   |   8%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ########7                             |  24%
#
# cmdstan-2.31.0       | 39.0 MB   | ##9                                   |   8%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ########9                             |  24%
# compiler-rt_osx-arm6 | 15.1 MB   | ###########7                          |  32%
#
# libclang-cpp14-14.0. | 13.1 MB   | #######################4              |  63%
# compiler-rt_osx-arm6 | 15.1 MB   | ###########7                          |  32%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #########                             |  24%
#
# cmdstan-2.31.0       | 39.0 MB   | ###                                   |   8%
# cmdstan-2.31.0       | 39.0 MB   | ###                                   |   8%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #########1                            |  25%
#
# libclang-cpp14-14.0. | 13.1 MB   | #######################9              |  65%
# cmdstan-2.31.0       | 39.0 MB   | ###1                                  |   8%
#
# libclang-cpp14-14.0. | 13.1 MB   | ########################1             |  65%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #########2                            |  25%
#
# libclang-cpp14-14.0. | 13.1 MB   | ########################3             |  66%
# cmdstan-2.31.0       | 39.0 MB   | ###1                                  |   8%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #########3                            |  25%
# cmdstan-2.31.0       | 39.0 MB   | ###1                                  |   9%
#
# libclang-cpp14-14.0. | 13.1 MB   | ########################5             |  66%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #########4                            |  26%
# compiler-rt_osx-arm6 | 15.1 MB   | ############2                         |  33%
#
# cmdstan-2.31.0       | 39.0 MB   | ###1                                  |   9%
# cmdstan-2.31.0       | 39.0 MB   | ###2                                  |   9%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #########5                            |  26%
#
# libclang-cpp14-14.0. | 13.1 MB   | ########################8             |  67%
# compiler-rt_osx-arm6 | 15.1 MB   | ############3                         |  33%
#
# cmdstan-2.31.0       | 39.0 MB   | ###2                                  |   9%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #########6                            |  26%
# compiler-rt_osx-arm6 | 15.1 MB   | ############4                         |  34%
#
# libclang-cpp14-14.0. | 13.1 MB   | #########################2            |  68%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #########7                            |  26%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ###2                                  |   9%
#
# libclang-cpp14-14.0. | 13.1 MB   | #########################3            |  69%
# compiler-rt_osx-arm6 | 15.1 MB   | ############5                         |  34%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ###3                                  |   9%
#
# libclang-cpp14-14.0. | 13.1 MB   | #########################7            |  70%
# compiler-rt_osx-arm6 | 15.1 MB   | ############7                         |  34%
# compiler-rt_osx-arm6 | 15.1 MB   | ############7                         |  35%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ###4                                  |   9%
#
# libclang-cpp14-14.0. | 13.1 MB   | #########################9            |  70%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##########################1           |  71%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##########2                           |  28%
# cmdstan-2.31.0       | 39.0 MB   | ###4                                  |   9%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##########################3           |  71%
# compiler-rt_osx-arm6 | 15.1 MB   | ############9                         |  35%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##########3                           |  28%
#
# cmdstan-2.31.0       | 39.0 MB   | ###5                                  |   9%
# compiler-rt_osx-arm6 | 15.1 MB   | #############                         |  35%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##########4                           |  28%
#
# cmdstan-2.31.0       | 39.0 MB   | ###5                                  |  10%
# compiler-rt_osx-arm6 | 15.1 MB   | #############1                        |  36%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##########################8           |  73%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##########5                           |  29%
# cmdstan-2.31.0       | 39.0 MB   | ###5                                  |  10%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###########################           |  73%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ###5                                  |  10%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###########################2          |  74%
# cmdstan-2.31.0       | 39.0 MB   | ###6                                  |  10%
#
# libclang-cpp14-14.0. | 13.1 MB   | ###########################5          |  74%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##########7                           |  29%
# compiler-rt_osx-arm6 | 15.1 MB   | #############4                        |  36%
#
# cmdstan-2.31.0       | 39.0 MB   | ###6                                  |  10%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##########9                           |  29%
# compiler-rt_osx-arm6 | 15.1 MB   | #############5                        |  37%
#
# cmdstan-2.31.0       | 39.0 MB   | ###6                                  |  10%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ###7                                  |  10%
#
# libclang-cpp14-14.0. | 13.1 MB   | ############################1         |  76%
# cmdstan-2.31.0       | 39.0 MB   | ###7                                  |  10%
#
# libclang-cpp14-14.0. | 13.1 MB   | ############################3         |  77%
# compiler-rt_osx-arm6 | 15.1 MB   | #############7                        |  37%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###########1                          |  30%
# cmdstan-2.31.0       | 39.0 MB   | ###7                                  |  10%
#
# libclang-cpp14-14.0. | 13.1 MB   | ############################5         |  77%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###########2                          |  30%
# cmdstan-2.31.0       | 39.0 MB   | ###8                                  |  10%
#
# libclang-cpp14-14.0. | 13.1 MB   | ############################8         |  78%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###########3                          |  31%
# cmdstan-2.31.0       | 39.0 MB   | ###8                                  |  10%
#
# libclang-cpp14-14.0. | 13.1 MB   | #############################2        |  79%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###########5                          |  31%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ###9                                  |  11%
#
# libclang-cpp14-14.0. | 13.1 MB   | #############################5        |  80%
# compiler-rt_osx-arm6 | 15.1 MB   | ##############1                       |  38%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ###9                                  |  11%
#
# libclang-cpp14-14.0. | 13.1 MB   | #############################9        |  81%
# compiler-rt_osx-arm6 | 15.1 MB   | ##############3                       |  39%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##############################2       |  82%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ####                                  |  11%
# compiler-rt_osx-arm6 | 15.1 MB   | ##############4                       |  39%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##############################4       |  82%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ####                                  |  11%
#
# libclang-cpp14-14.0. | 13.1 MB   | ##############################7       |  83%
# compiler-rt_osx-arm6 | 15.1 MB   | ##############5                       |  39%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ####                                  |  11%
# compiler-rt_osx-arm6 | 15.1 MB   | ##############6                       |  40%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ############1                         |  33%
#
# ...
#
#
# cmdstan-2.31.0       | 39.0 MB   | #########4                            |  26%
# cmdstan-2.31.0       | 39.0 MB   | #########5                            |  26%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #########5                            |  26%
# compiler-rt_osx-arm6 | 15.1 MB   | ###########################5          |  74%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #########6                            |  26%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #############################6        |  80%
# cmdstan-2.31.0       | 39.0 MB   | #########7                            |  26%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #############################7        |  80%
# compiler-rt_osx-arm6 | 15.1 MB   | ###########################7          |  75%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #########8                            |  27%
# cmdstan-2.31.0       | 39.0 MB   | ##########                            |  27%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##########1                           |  27%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##############################2       |  82%
# cmdstan-2.31.0       | 39.0 MB   | ##########2                           |  28%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##############################3       |  82%
# cmdstan-2.31.0       | 39.0 MB   | ##########2                           |  28%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##############################4       |  82%
# cmdstan-2.31.0       | 39.0 MB   | ##########3                           |  28%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##########4                           |  28%
# cmdstan-2.31.0       | 39.0 MB   | ##########5                           |  28%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##############################7       |  83%
# cmdstan-2.31.0       | 39.0 MB   | ##########5                           |  29%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##############################8       |  83%
# cmdstan-2.31.0       | 39.0 MB   | ##########7                           |  29%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##############################9       |  84%
# cmdstan-2.31.0       | 39.0 MB   | ##########8                           |  29%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###############################       |  84%
# cmdstan-2.31.0       | 39.0 MB   | ##########9                           |  30%
# cmdstan-2.31.0       | 39.0 MB   | ##########9                           |  30%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ###########                           |  30%
# compiler-rt_osx-arm6 | 15.1 MB   | ############################7         |  78%
# cmdstan-2.31.0       | 39.0 MB   | ###########1                          |  30%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ###########2                          |  30%
# compiler-rt_osx-arm6 | 15.1 MB   | ############################8         |  78%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ###########2                          |  30%
# compiler-rt_osx-arm6 | 15.1 MB   | ############################8         |  78%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ###########6                          |  31%
# compiler-rt_osx-arm6 | 15.1 MB   | ############################9         |  78%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ###########7                          |  32%
# compiler-rt_osx-arm6 | 15.1 MB   | ############################9         |  78%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ###########8                          |  32%
# cmdstan-2.31.0       | 39.0 MB   | ###########9                          |  32%
# cmdstan-2.31.0       | 39.0 MB   | ############                          |  33%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ############1                         |  33%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ############3                         |  33%
# cmdstan-2.31.0       | 39.0 MB   | ############4                         |  34%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###############################8      |  86%
# cmdstan-2.31.0       | 39.0 MB   | ############5                         |  34%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###############################9      |  86%
# cmdstan-2.31.0       | 39.0 MB   | ############6                         |  34%
# compiler-rt_osx-arm6 | 15.1 MB   | #############################3        |  79%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ############7                         |  34%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ############8                         |  35%
# compiler-rt_osx-arm6 | 15.1 MB   | #############################4        |  80%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #############                         |  35%
# compiler-rt_osx-arm6 | 15.1 MB   | #############################5        |  80%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #############1                        |  35%
# compiler-rt_osx-arm6 | 15.1 MB   | #############################6        |  80%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #############2                        |  36%
# compiler-rt_osx-arm6 | 15.1 MB   | #############################7        |  80%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #############3                        |  36%
# compiler-rt_osx-arm6 | 15.1 MB   | #############################7        |  81%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #############4                        |  36%
# cmdstan-2.31.0       | 39.0 MB   | #############5                        |  37%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #############6                        |  37%
# compiler-rt_osx-arm6 | 15.1 MB   | #############################9        |  81%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #############6                        |  37%
# cmdstan-2.31.0       | 39.0 MB   | #############7                        |  37%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #############8                        |  38%
# cmdstan-2.31.0       | 39.0 MB   | #############9                        |  38%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##############1                       |  38%
# compiler-rt_osx-arm6 | 15.1 MB   | ##############################1       |  82%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##############2                       |  39%
# cmdstan-2.31.0       | 39.0 MB   | ##############7                       |  40%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #################################3    |  90%
# cmdstan-2.31.0       | 39.0 MB   | ##############9                       |  40%
# cmdstan-2.31.0       | 39.0 MB   | ###############1                      |  41%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | #################################5    |  91%
# compiler-rt_osx-arm6 | 15.1 MB   | ##############################5       |  82%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ###############3                      |  41%
# compiler-rt_osx-arm6 | 15.1 MB   | ##############################6       |  83%
# compiler-rt_osx-arm6 | 15.1 MB   | ##############################6       |  83%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ###############4                      |  42%
# compiler-rt_osx-arm6 | 15.1 MB   | ##############################7       |  83%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ###############6                      |  42%
# compiler-rt_osx-arm6 | 15.1 MB   | ##############################9       |  84%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ###############7                      |  43%
# cmdstan-2.31.0       | 39.0 MB   | ###############8                      |  43%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##################################3   |  93%
# compiler-rt_osx-arm6 | 15.1 MB   | ###############################1      |  84%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ################                      |  43%
# compiler-rt_osx-arm6 | 15.1 MB   | ###############################2      |  85%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ################1                     |  44%
# cmdstan-2.31.0       | 39.0 MB   | ################2                     |  44%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ################3                     |  44%
# compiler-rt_osx-arm6 | 15.1 MB   | ###############################5      |  85%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ################4                     |  44%
# compiler-rt_osx-arm6 | 15.1 MB   | ###############################6      |  85%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ################5                     |  45%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###################################   |  95%
# cmdstan-2.31.0       | 39.0 MB   | ################5                     |  45%
# compiler-rt_osx-arm6 | 15.1 MB   | ###############################8      |  86%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ################6                     |  45%
# cmdstan-2.31.0       | 39.0 MB   | ################7                     |  45%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ################8                     |  45%
# compiler-rt_osx-arm6 | 15.1 MB   | ###############################9      |  86%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###################################4  |  96%
# cmdstan-2.31.0       | 39.0 MB   | ################8                     |  46%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ################9                     |  46%
# cmdstan-2.31.0       | 39.0 MB   | ################9                     |  46%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###################################6  |  96%
# cmdstan-2.31.0       | 39.0 MB   | #################                     |  46%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #################1                    |  46%
# cmdstan-2.31.0       | 39.0 MB   | #################1                    |  46%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###################################8  |  97%
# cmdstan-2.31.0       | 39.0 MB   | #################2                    |  47%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ###################################9  |  97%
# cmdstan-2.31.0       | 39.0 MB   | #################2                    |  47%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #################3                    |  47%
# cmdstan-2.31.0       | 39.0 MB   | #################4                    |  47%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ####################################1 |  98%
# cmdstan-2.31.0       | 39.0 MB   | #################4                    |  47%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ####################################2 |  98%
# cmdstan-2.31.0       | 39.0 MB   | #################5                    |  47%
# compiler-rt_osx-arm6 | 15.1 MB   | ################################7     |  89%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #################5                    |  48%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #################6                    |  48%
# cmdstan-2.31.0       | 39.0 MB   | #################6                    |  48%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #################7                    |  48%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ####################################5 |  99%
# cmdstan-2.31.0       | 39.0 MB   | #################7                    |  48%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ####################################6 |  99%
# cmdstan-2.31.0       | 39.0 MB   | #################8                    |  48%
#
#
# cmdstan-2.31.0       | 39.0 MB   | #################9                    |  49%
# compiler-rt_osx-arm6 | 15.1 MB   | #################################1    |  90%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##################                    |  49%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##################################### | 100%
# compiler-rt_osx-arm6 | 15.1 MB   | #################################2    |  90%
#
#
# llvm-tools-14.0.6    | 10.4 MB   | ##################################### | 100%
#
#
# cmdstan-2.31.0       | 39.0 MB   | ##################1                   |  49%
# cmdstan-2.31.0       | 39.0 MB   | ##################2                   |  49%
# cmdstan-2.31.0       | 39.0 MB   | ##################3                   |  50%
# cmdstan-2.31.0       | 39.0 MB   | ##################4                   |  50%
# compiler-rt_osx-arm6 | 15.1 MB   | #################################6    |  91%
# cmdstan-2.31.0       | 39.0 MB   | ##################4                   |  50%
# cmdstan-2.31.0       | 39.0 MB   | ##################8                   |  51%
# cmdstan-2.31.0       | 39.0 MB   | ##################9                   |  51%
# cmdstan-2.31.0       | 39.0 MB   | ###################1                  |  52%
# cmdstan-2.31.0       | 39.0 MB   | ###################2                  |  52%
# compiler-rt_osx-arm6 | 15.1 MB   | ##################################3   |  93%
# cmdstan-2.31.0       | 39.0 MB   | ###################3                  |  52%
# cmdstan-2.31.0       | 39.0 MB   | ###################3                  |  52%
# cmdstan-2.31.0       | 39.0 MB   | ###################4                  |  53%
# cmdstan-2.31.0       | 39.0 MB   | ###################5                  |  53%
# cmdstan-2.31.0       | 39.0 MB   | ###################6                  |  53%
# cmdstan-2.31.0       | 39.0 MB   | ###################7                  |  53%
# cmdstan-2.31.0       | 39.0 MB   | ###################8                  |  54%
# cmdstan-2.31.0       | 39.0 MB   | ###################9                  |  54%
# cmdstan-2.31.0       | 39.0 MB   | ####################2                 |  55%
# cmdstan-2.31.0       | 39.0 MB   | ####################3                 |  55%
# cmdstan-2.31.0       | 39.0 MB   | ####################4                 |  55%
# cmdstan-2.31.0       | 39.0 MB   | ####################5                 |  56%
# cmdstan-2.31.0       | 39.0 MB   | ####################6                 |  56%
# cmdstan-2.31.0       | 39.0 MB   | ####################7                 |  56%
# cmdstan-2.31.0       | 39.0 MB   | ####################7                 |  56%
# cmdstan-2.31.0       | 39.0 MB   | ####################8                 |  56%
# cmdstan-2.31.0       | 39.0 MB   | ####################9                 |  57%
# cmdstan-2.31.0       | 39.0 MB   | #####################                 |  57%
# cmdstan-2.31.0       | 39.0 MB   | #####################1                |  57%
# cmdstan-2.31.0       | 39.0 MB   | #####################1                |  57%
# cmdstan-2.31.0       | 39.0 MB   | #####################2                |  57%
# cmdstan-2.31.0       | 39.0 MB   | #####################3                |  58%
# cmdstan-2.31.0       | 39.0 MB   | #####################4                |  58%
# cmdstan-2.31.0       | 39.0 MB   | #####################5                |  58%
# compiler-rt_osx-arm6 | 15.1 MB   | ####################################9 | 100%
# cmdstan-2.31.0       | 39.0 MB   | ######################3               |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
from prophet import Prophet

# %%
# Prepare data for Prophet
prophet_data = one_pizza.reset_index()
prophet_data.columns = ['ds', 'y']

# Train-Test Split
prophet_train = prophet_data[:-30]
prophet_test = prophet_data[-30:]

# Fit Prophet Model
prophet_model = Prophet()
prophet_model.fit(prophet_train)

# Forecast
future_dates = prophet_model.make_future_dataframe(periods=30)
prophet_forecast = prophet_model.predict(future_dates)

# Extract only test period forecast
prophet_test_forecast = prophet_forecast[-30:]['yhat']

# Evaluate Prophet Model
prophet_mape = mean_absolute_percentage_error(prophet_test['y'], prophet_test_forecast)

print("Prophet Model MAPE:", prophet_mape)
# Out:
# 16:15:16 - cmdstanpy - INFO - Chain [1] start processing
# 16:15:16 - cmdstanpy - INFO - Chain [1] done processing
# Prophet Model MAPE: 0.43721543386407047

# %%
print(f"ARIMA Model MAPE: {arima_mape}")
print(f"SARIMA Model MAPE: {sarima_mape}")
print(f"Prophet Model MAPE: {prophet_mape}")
# Out:
# ARIMA Model MAPE: 0.49021344525474375
# SARIMA Model MAPE: 0.4439493435625872
# Prophet Model MAPE: 0.43721543386407047

# %%
Based on the provided MAPE (Mean Absolute Percentage Error) values, Prophet has the lowest MAPE, making it the best-performing model for our dataset. Prophet is handling seasonality and trends effectively.

# %%
Sales Forecasting: Predicting pizza sales for the next one week using the trained Prophet model.

# %%
# Initialize dictionary to store forecasts
all_forecasts = {}

# Loop through each pizza type
for pizza in data.columns:  # data contains daily sales of each pizza
    one_pizza_sales = data[pizza].reset_index()
    one_pizza_sales.columns = ['ds', 'y']  # Prophet requires columns ['ds', 'y']

    # Instantiate a new Prophet model for each pizza type
    prophet_model = Prophet()
    prophet_model.fit(one_pizza_sales)

    # Forecast for the next 7 days
    future_dates = prophet_model.make_future_dataframe(periods=7)
    forecast = prophet_model.predict(future_dates)
    
    # Store forecasted values (last 7 days)
    all_forecasts[pizza] = forecast.iloc[-7:]['yhat'].values

# Convert forecasts into a DataFrame
forecast_df = pd.DataFrame(all_forecasts)
forecast_df.index = pd.date_range(start=data.index[-1] + pd.Timedelta(days=1), periods=7)
forecast_df
# Out:
# 16:18:26 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:26 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:26 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:26 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:26 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:27 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:28 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:29 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:29 - cmdstanpy - INFO - Chain [1] done processing
# 16:18:29 - cmdstanpy - INFO - Chain [1] start processing
# 16:18:29 - cmdstanpy - INFO - Chain [1] done processing
#             The Barbecue Chicken Pizza  The Big Meat Pizza  \
# 2016-01-01                    7.037739            4.949716
# 2016-01-02                    6.299012            5.027071
# 2016-01-03                    4.700611            4.362276
# 2016-01-04                    5.347252            4.649328
# 2016-01-05                    5.724104            4.314808
# 2016-01-06                    5.398813            4.603469
# 2016-01-07                    6.447002            5.006358
#
#             The Brie Carre Pizza  The Calabrese Pizza  \
# 2016-01-01              1.484724             2.830293
# 2016-01-02              1.217387             2.839403
# 2016-01-03              1.511221             2.281557
# 2016-01-04              1.443492             3.089175
# 2016-01-05              1.583449             2.743205
# 2016-01-06              1.602660             2.897065
# 2016-01-07              1.737835             2.841661
#
#             The California Chicken Pizza  The Chicken Alfredo Pizza  \
# 2016-01-01                      6.831076                   3.357056
# 2016-01-02                      5.812968                   2.940254
# 2016-01-03                      5.035788                   2.155344
# 2016-01-04                      5.952815                   2.757591
# 2016-01-05                      5.332045                   2.498320
# 2016-01-06                      5.639620                   2.536871
# 2016-01-07                      5.995102                   2.742667
#
#             The Chicken Pesto Pizza  The Classic Deluxe Pizza  \
# 2016-01-01                 3.192946                  7.662466
# 2016-01-02                 2.469505                  7.082125
# 2016-01-03                 2.500333                  5.786069
# 2016-01-04                 2.770995                  6.822263
# 2016-01-05                 2.004700                  6.947639
# 2016-01-06                 2.762564                  6.601794
# 2016-01-07                 2.953265                  6.950341
#
#             The Five Cheese Pizza  The Four Cheese Pizza  ...  \
# 2016-01-01               3.986472               5.642348  ...
# 2016-01-02               2.943221               5.579987  ...
# 2016-01-03               2.775785               4.391448  ...
# 2016-01-04               3.027510               4.721162  ...
# 2016-01-05               3.580675               4.733678  ...
# 2016-01-06               3.118027               5.271875  ...
# 2016-01-07               3.522481               5.732380  ...
#
#             The Prosciutto and Arugula Pizza  The Sicilian Pizza  \
# 2016-01-01                          4.646700            5.979711
# 2016-01-02                          3.738119            5.980806
# 2016-01-03                          3.615496            4.333204
# 2016-01-04                          3.667232            4.339596
# 2016-01-05                          4.219201            4.770138
# 2016-01-06                          3.757702            5.385250
# 2016-01-07                          3.752076            5.354277
#
#             The Soppressata Pizza  The Southwest Chicken Pizza  \
# 2016-01-01               2.857031                     5.799963
# 2016-01-02               2.553577                     4.977274
# 2016-01-03               2.135569                     4.232770
# 2016-01-04               2.137269                     5.258924
# 2016-01-05               3.034162                     5.073231
# 2016-01-06               2.572555                     4.765091
# 2016-01-07               2.601260                     5.407071
#
#             The Spicy Italian Pizza  The Spinach Pesto Pizza  \
# 2016-01-01                 5.562465                 3.406552
# 2016-01-02                 5.325846                 2.739452
# 2016-01-03                 4.235173                 2.497895
# 2016-01-04                 4.718979                 2.448622
# 2016-01-05                 5.033707                 2.720316
# 2016-01-06                 4.994072                 2.432331
# 2016-01-07                 5.584877                 2.637972
#
#             The Spinach Supreme Pizza  The Spinach and Feta Pizza  \
# 2016-01-01                   2.942635                    4.571350
# 2016-01-02                   2.346077                    3.470653
# 2016-01-03                   2.006320                    3.366378
# 2016-01-04                   2.183903                    3.951960
# 2016-01-05                   2.211541                    3.355147
# 2016-01-06                   2.250036                    3.835934
# 2016-01-07                   2.464121                    4.005309
#
#             The Thai Chicken Pizza  The Vegetables + Vegetables Pizza
# 2016-01-01                6.730517                           4.380341
# 2016-01-02                6.413685                           4.366873
# 2016-01-03                5.481311                           3.768258
# 2016-01-04                6.850571                           3.962792
# 2016-01-05                6.144613                           3.542590
# 2016-01-06                5.971623                           4.293515
# 2016-01-07                6.519851                           4.510612
#
# [7 rows x 32 columns]

# %%
# Round the forecasted number of pizzas to the nearest whole number
forecast_df = forecast_df.round()

# Display the updated forecast DataFrame
forecast_df
# Out:
#             The Barbecue Chicken Pizza  The Big Meat Pizza  \
# 2016-01-01                         7.0                 5.0
# 2016-01-02                         6.0                 5.0
# 2016-01-03                         5.0                 4.0
# 2016-01-04                         5.0                 5.0
# 2016-01-05                         6.0                 4.0
# 2016-01-06                         5.0                 5.0
# 2016-01-07                         6.0                 5.0
#
#             The Brie Carre Pizza  The Calabrese Pizza  \
# 2016-01-01                   1.0                  3.0
# 2016-01-02                   1.0                  3.0
# 2016-01-03                   2.0                  2.0
# 2016-01-04                   1.0                  3.0
# 2016-01-05                   2.0                  3.0
# 2016-01-06                   2.0                  3.0
# 2016-01-07                   2.0                  3.0
#
#             The California Chicken Pizza  The Chicken Alfredo Pizza  \
# 2016-01-01                           7.0                        3.0
# 2016-01-02                           6.0                        3.0
# 2016-01-03                           5.0                        2.0
# 2016-01-04                           6.0                        3.0
# 2016-01-05                           5.0                        2.0
# 2016-01-06                           6.0                        3.0
# 2016-01-07                           6.0                        3.0
#
#             The Chicken Pesto Pizza  The Classic Deluxe Pizza  \
# 2016-01-01                      3.0                       8.0
# 2016-01-02                      2.0                       7.0
# 2016-01-03                      3.0                       6.0
# 2016-01-04                      3.0                       7.0
# 2016-01-05                      2.0                       7.0
# 2016-01-06                      3.0                       7.0
# 2016-01-07                      3.0                       7.0
#
#             The Five Cheese Pizza  The Four Cheese Pizza  ...  \
# 2016-01-01                    4.0                    6.0  ...
# 2016-01-02                    3.0                    6.0  ...
# 2016-01-03                    3.0                    4.0  ...
# 2016-01-04                    3.0                    5.0  ...
# 2016-01-05                    4.0                    5.0  ...
# 2016-01-06                    3.0                    5.0  ...
# 2016-01-07                    4.0                    6.0  ...
#
#             The Prosciutto and Arugula Pizza  The Sicilian Pizza  \
# 2016-01-01                               5.0                 6.0
# 2016-01-02                               4.0                 6.0
# 2016-01-03                               4.0                 4.0
# 2016-01-04                               4.0                 4.0
# 2016-01-05                               4.0                 5.0
# 2016-01-06                               4.0                 5.0
# 2016-01-07                               4.0                 5.0
#
#             The Soppressata Pizza  The Southwest Chicken Pizza  \
# 2016-01-01                    3.0                          6.0
# 2016-01-02                    3.0                          5.0
# 2016-01-03                    2.0                          4.0
# 2016-01-04                    2.0                          5.0
# 2016-01-05                    3.0                          5.0
# 2016-01-06                    3.0                          5.0
# 2016-01-07                    3.0                          5.0
#
#             The Spicy Italian Pizza  The Spinach Pesto Pizza  \
# 2016-01-01                      6.0                      3.0
# 2016-01-02                      5.0                      3.0
# 2016-01-03                      4.0                      2.0
# 2016-01-04                      5.0                      2.0
# 2016-01-05                      5.0                      3.0
# 2016-01-06                      5.0                      2.0
# 2016-01-07                      6.0                      3.0
#
#             The Spinach Supreme Pizza  The Spinach and Feta Pizza  \
# 2016-01-01                        3.0                         5.0
# 2016-01-02                        2.0                         3.0
# 2016-01-03                        2.0                         3.0
# 2016-01-04                        2.0                         4.0
# 2016-01-05                        2.0                         3.0
# 2016-01-06                        2.0                         4.0
# 2016-01-07                        2.0                         4.0
#
#             The Thai Chicken Pizza  The Vegetables + Vegetables Pizza
# 2016-01-01                     7.0                                4.0
# 2016-01-02                     6.0                                4.0
# 2016-01-03                     5.0                                4.0
# 2016-01-04                     7.0                                4.0
# 2016-01-05                     6.0                                4.0
# 2016-01-06                     6.0                                4.0
# 2016-01-07                     7.0                                5.0
#
# [7 rows x 32 columns]

# %%
Ingredient Calculation

# %%
ingredients = pd.read_excel('Pizza_ingredients.xlsx')
ingredients.head()
# Out:
#   pizza_name_id                  pizza_name  pizza_ingredients  \
# 0     bbq_ckn_l  The Barbecue Chicken Pizza  Barbecued Chicken
# 1     bbq_ckn_l  The Barbecue Chicken Pizza        Red Peppers
# 2     bbq_ckn_l  The Barbecue Chicken Pizza      Green Peppers
# 3     bbq_ckn_l  The Barbecue Chicken Pizza           Tomatoes
# 4     bbq_ckn_l  The Barbecue Chicken Pizza         Red Onions
#
#    Items_Qty_In_Grams
# 0                40.0
# 1                15.0
# 2                20.0
# 3                30.0
# 4                60.0

# %%
ingredients.nunique()
# Out:
# pizza_name_id         91
# pizza_name            32
# pizza_ingredients     64
# Items_Qty_In_Grams    17
# dtype: int64

# %%
ingredient_forecast = []

# Loop through each pizza in forecast_df
for pizza in forecast_df.columns:
    # Get the total forecasted sales for the pizza (sum across 7 days)
    total_sales = forecast_df[pizza].sum()

    # Get the ingredient requirements for the pizza from ingredients_data
    pizza_ingredients = ingredients[ingredients['pizza_name'] == pizza]
    
    # Calculate total ingredient requirements
    for _, row in pizza_ingredients.iterrows():
        ingredient_forecast.append({
            'ingredient': row['pizza_ingredients'],  # Ingredient name
            'quantity_needed': total_sales * row['Items_Qty_In_Grams']  # Forecast * quantity per pizza
        })

# Convert to DataFrame
ingredient_forecast_df = pd.DataFrame(ingredient_forecast)

# Summarize by ingredient
final_purchase_order = ingredient_forecast_df.groupby('ingredient').agg({'quantity_needed': 'sum'}).reset_index()

# Add a unit column (e.g., grams)
final_purchase_order['unit'] = 'grams'

# Display the final purchase order
print("Final Purchase Order:")
pd.set_option('display.max_rows',64)
final_purchase_order
# Out:
# Final Purchase Order:
#                     ingredient  quantity_needed   unit
# 0                 ?duja Salami           2400.0  grams
# 1                Alfredo Sauce            855.0  grams
# 2                    Anchovies           2295.0  grams
# 3                   Artichokes           6705.0  grams
# 4                      Arugula            870.0  grams
# 5                Asiago Cheese           3660.0  grams
# 6                        Bacon          18180.0  grams
# 7               Barbecue Sauce           1200.0  grams
# 8            Barbecued Chicken           3600.0  grams
# 9             Beef Chuck Roast          15960.0  grams
# 10                 Blue Cheese            720.0  grams
# 11           Brie Carre Cheese            330.0  grams
# 12            Calabrese Salami           9900.0  grams
# 13                   Capocollo          36300.0  grams
# 14          Caramelized Onions              0.0  grams
# 15                     Chicken          47400.0  grams
# 16              Chipotle Sauce           3840.0  grams
# 17             Chorizo Sausage           1650.0  grams
# 18                    Cilantro           1920.0  grams
# 19      Coarse Sicilian Salami           8400.0  grams
# 20                        Corn          12800.0  grams
# 21                    Eggplant           2280.0  grams
# 22                 Feta Cheese          10430.0  grams
# 23              Fontina Cheese           3600.0  grams
# 24         Friggitello Peppers            600.0  grams
# 25                      Garlic          15980.0  grams
# 26                Genoa Salami           4860.0  grams
# 27                 Goat Cheese           7320.0  grams
# 28  Gorgonzola Piccante Cheese           2220.0  grams
# 29                Gouda Cheese           2460.0  grams
# 30                Green Olives           3420.0  grams
# 31               Green Peppers           5060.0  grams
# 32             Italian Sausage            330.0  grams
# 33            Jalapeno Peppers           3150.0  grams
# 34             Kalamata Olives           3150.0  grams
# 35            Luganega Sausage           4200.0  grams
# 36           Mozzarella Cheese          10290.0  grams
# 37                   Mushrooms          22080.0  grams
# 38                      Onions           2100.0  grams
# 39                     Oregano            750.0  grams
# 40                    Pancetta           3600.0  grams
# 41  Parmigiano Reggiano Cheese           5550.0  grams
# 42                       Pears            110.0  grams
# 43           Peperoncini verdi           1080.0  grams
# 44                   Pepperoni          20850.0  grams
# 45                 Pesto Sauce           3360.0  grams
# 46                   Pineapple           8190.0  grams
# 47               Plum Tomatoes           2400.0  grams
# 48                  Prosciutto            330.0  grams
# 49   Prosciutto di San Daniele           2030.0  grams
# 50            Provolone Cheese            720.0  grams
# 51                  Red Onions          49440.0  grams
# 52                 Red Peppers           9240.0  grams
# 53              Ricotta Cheese           2775.0  grams
# 54               Romano Cheese            720.0  grams
# 55                  Sliced Ham              0.0  grams
# 56         Smoked Gouda Cheese            720.0  grams
# 57          Soppressata Salami           5700.0  grams
# 58                     Spinach          16830.0  grams
# 59          Sun-dried Tomatoes           1140.0  grams
# 60     Thai Sweet Chilli Sauce           2640.0  grams
# 61                       Thyme             55.0  grams
# 62                    Tomatoes          32400.0  grams
# 63                    Zucchini           2880.0  grams
